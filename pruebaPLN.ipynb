# %% [markdown]
# # Primeras Pruebas de PLN de Azure: Grupo DLL

# %% [markdown]
# ```Python
# # Instalacion necesaria
# pip install azure-ai-textanalytics

# %%
from azure.ai.textanalytics import TextAnalyticsClient
from azure.core.credentials import AzureKeyCredential

# Configura tus credenciales
endpoint = "https://proyectoazureplndll.cognitiveservices.azure.com/"
key = ""

# Cliente
client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# %% [markdown]
# ### Crear cliente

# %%
client = TextAnalyticsClient(endpoint=endpoint, credential=AzureKeyCredential(key))

# %% [markdown]
# ### Documentos de prueba

# %%
documents = [
        "Me encanta aprender el lenguaje de programación Python y trabajar con Azure!",
            "jfevufuwfk"
            ]
]

# %% [markdown]
# ### Llamada de prueba: análisis de sentimiento

# %%
response = client.analyze_sentiment(documents=documents)

# %% [markdown]
# ### Imprimir resultados

# %%
for idx, doc in enumerate(response):
    print(f"Documento {idx+1}:")
    print(f"  Texto: {documents[idx]}")
    print(f"  Sentimiento: {doc.sentiment}")
    print(f"  Confianza: {doc.confidence_scores}")
# Out:
# Documento 1:
#   Texto: Me encanta aprender el lenguaje de programación Python y trabajar con Azure!
#   Sentimiento: positive
#   Confianza: {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0}
# Documento 2:
#   Texto: Worst day ever at the office, madre de dios, un dia increible.
#   Sentimiento: negative
#   Confianza: {'positive': 0.0, 'neutral': 0.0, 'negative': 1.0}

# %%
help(client)
# Out:
# Help on TextAnalyticsClient in module azure.ai.textanalytics._text_analytics_client object:
#
# class TextAnalyticsClient(azure.ai.textanalytics._base_client.TextAnalyticsClientBase)
#  |  TextAnalyticsClient(
#  |      endpoint: str,
#  |      credential: Union[azure.core.credentials.AzureKeyCredential, azure.core.credentials.TokenCredential],
#  |      *,
#  |      default_language: Optional[str] = None,
#  |      default_country_hint: Optional[str] = None,
#  |      api_version: Union[str, azure.ai.textanalytics._base_client.TextAnalyticsApiVersion, NoneType] = None,
#  |      **kwargs: Any
#  |  ) -> None
#  |
#  |  The Language service API is a suite of natural language processing (NLP) skills built with the best-in-class
#  |  Microsoft machine learning algorithms. The API can be used to analyze unstructured text for
#  |  tasks such as sentiment analysis, key phrase extraction, entities recognition,
#  |  and language detection, and more.
#  |
# ...

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analyze_result_callback',
#  '_api_version',
#  '_client',
#  '_default_country_hint',
#  '_default_language',
#  '_healthcare_result_callback',
#  '_string_index_type_default',
#  'analyze_sentiment',
#  'begin_abstract_summary',
#  'begin_analyze_actions',
#  'begin_analyze_healthcare_entities',
#  'begin_extract_summary',
#  'begin_multi_label_classify',
#  'begin_recognize_custom_entities',
#  'begin_single_label_classify',
#  'close',
#  'detect_language',
# ...

# %%
response2 = client.detect_language(documents=documents)



for idx, doc in enumerate(response2):
    if not doc.is_error:
        print(f"Documento {idx+1}:")
        print(f"  Texto: {documents[idx]}")
        print(f"  Idioma detectado: {doc.primary_language.name}")
        print(f"  Código: {doc.primary_language.iso6391_name}")
        print(f"  Confianza: {doc.primary_language.confidence_score}")
        print(f"  Estadísticas: {doc.statistics}")
    else:
        print(f"Documento {idx+1} tuvo un error: {doc.error}")
# Out:
# Documento 1:
#   Texto: Me encanta aprender el lenguaje de programación Python y trabajar con Azure!
#   Idioma detectado: Spanish
#   Código: es
#   Confianza: 1.0
#   Estadísticas: None
# Documento 2:
#   Texto: jfevufuwfk
#   Idioma detectado: English
#   Código: en
#   Confianza: 0.89
#   Estadísticas: None

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analyze_result_callback',
#  '_api_version',
#  '_client',
#  '_default_country_hint',
#  '_default_language',
#  '_healthcare_result_callback',
#  '_string_index_type_default',
#  'analyze_sentiment',
#  'begin_abstract_summary',
#  'begin_analyze_actions',
#  'begin_analyze_healthcare_entities',
#  'begin_extract_summary',
#  'begin_multi_label_classify',
#  'begin_recognize_custom_entities',
#  'begin_single_label_classify',
#  'close',
#  'detect_language',
# ...

# %%
response3 = client.recognize_entities(documents=documents)

# %%
response3 = client.recognize_entities(documents=documents)

for idx, doc in enumerate(response3):
    print(f"Documento {idx+1}: {documents[idx]}")
    if not doc.is_error:
        if doc.entities:
            for entity in doc.entities:
                print(f"  Entidad: {entity.text}")
                print(f"    Tipo: {entity.category}")
                print(f"    Subtipo: {entity.subcategory}")
                print(f"    Confianza: {entity.confidence_score}")
        else:
            print("  No se encontraron entidades.")
    else:
        print(f"  Error: {doc.error}")
# Out:
# Documento 1: Me encanta aprender el lenguaje de programación Python y trabajar con Azure!
#   Entidad: programación
#     Tipo: Skill
#     Subtipo: None
#     Confianza: 0.66
#   Entidad: Python
#     Tipo: Skill
#     Subtipo: None
#     Confianza: 1.0
#   Entidad: Azure
#     Tipo: Product
#     Subtipo: ComputingProduct
#     Confianza: 1.0
# Documento 2: jfevufuwfk Worst day ever at the office, madre de dios, un dia increible.
#   Entidad: office
#     Tipo: Location
#     Subtipo: Structural
#     Confianza: 0.78

# %% [markdown]
# ```Python
# # Instalar para leer pdfs
# pip install PyPDF2

# %% [markdown]
# Vamos a probar con un PDF

# %%
import PyPDF2

pdf_papdf_path = r"C:\Users\iabd\Documents\A5T1_OmarLlinares.pdf"

# %%
# --- Abrir PDF y extraer todo el texto de golpe ---
with open(pdf_papdf_path, "rb") as file:
    reader = PyPDF2.PdfReader(file)
    text = reader.pages[0].extract_text()  # si es corto y tiene una sola página

# --- Enviar a Azure para resumen ---
documents = [text]  # lista con un solo documento
response4 = client.analyze_sentiment(documents=documents)  # o el método de resumen que corresponda
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 8
#       6 # --- Enviar a Azure para resumen ---
#       7 documents = [text]  # lista con un solo documento
# ----> 8 response4 = client.analyze_sentiment(pdf_papdf_path)
#
# File c:\Users\iabd\anaconda3\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# ...

# %%
print(response4)
# Out:
# [AnalyzeSentimentResult(id=0, sentiment=negative, warnings=[], statistics=None, confidence_scores=SentimentConfidenceScores(positive=0.02, neutral=0.28, negative=0.7), sentences=[SentenceSentiment(text=Omar Llinares  Care aga  IES Marcos Za ragoza     Big D ata  Actividad 1.5   Contesta a las siguientes preguntas justificando tus respuestas:   1. Cuando vamos a diseñar un pipeline para la ingesta de datos, ¿Cuál es el primer  paso que debemos considerar?   , sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.01, neutral=0.98, negative=0.01), length=259, offset=0, mined_opinions=[]), SentenceSentiment(text=La ingesta  de los dat os. , sentiment=neutral, confidence_scores=SentimentConfidenceScores(positive=0.04, neutral=0.9, negative=0.05), length=27, offset=259, mined_opinions=[]), SentenceSentiment(text=Origen y forma to de los datos, Latencia/Disponibilidad,  Actuali zaciones, Tra nsformaciones, Destino de los datos.   , sentiment=neutral, confidence_scores=Se
# ...

# %%
dir(response4)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
